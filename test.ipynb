# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\nidhi\\anaconda3\\envs\\ml_new\\python.exe'

# %%
# !pip install langchain langchain-openai faiss-cpu pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-openai in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (1.1.11)
# Requirement already satisfied: faiss-cpu in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (1.13.2)
# Requirement already satisfied: pypdf in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (6.8.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain) (1.2.18)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.10)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-openai) (2.26.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.3.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from faiss-cpu) (2.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: colorama in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)

# %%
# !pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (1.2.18)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.48-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.3-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (0.7.16)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-community) (2.0.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl.metadata (82 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\nidhi\anaconda3\envs\ml_new\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 20.8 MB/s  0:00:00
# Downloading aiohttp-3.13.3-cp310-cp310-win_amd64.whl (456 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.2-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB ?  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.48-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 29.8 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl (87 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl (230 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp310-cp310-win_amd64.whl (41 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, async-timeout, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain-community
#
#    -------- -------------------------------  4/20 [marshmallow]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------------ --------- 15/20 [dataclasses-json]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    ---------------------------------------- 20/20 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.48 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 async-timeout-4.0.3 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.3.2 httpx-sse-0.4.3 langchain-classic-1.0.2 langchain-community-0.4.1 langchain-text-splitters-1.1.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.13.1 python-dotenv-1.2.2 typing-inspect-0.9.0 yarl-1.23.0

# %%
# %pip install langchain
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.llms import Ollama
from langchain.chains import RetrievalQA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       4 from langchain_community.embeddings import HuggingFaceEmbeddings
#       5 from langchain_community.llms import Ollama
# ----> 6 from langchain.chains import RetrievalQA
#
# ModuleNotFoundError: No module named 'langchain.chains'
